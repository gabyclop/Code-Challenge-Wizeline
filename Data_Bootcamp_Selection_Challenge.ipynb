# %%
import pandas as pd
import numpy as np

# %%
url='https://drive.google.com/file/d/1PCJ7ltluquoXKi6MYTPMfwZQNI_-MIFP/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
answer_dict =  {"Q1" : None,
                "Q2" : None,
                "Q3" : None,
                "Q4" : None,
                "Q5" : None,
                "Q6" : None,
                "Q7" : None}

# %%
# Q1
mean = df['CO2 Emission Grams/Mile'].mean()

# %%
answer_dict["Q1"] = mean

# %%
answer_dict["Q1"]
# Out:
# 475.31633925715045

# %%
#Q2
df1 = df.filter(items=['Make', 'Model'])

# %%
s = df1.groupby('Make').Model.nunique()

# %%
s1 = s.sort_values(ascending=False)

# %%
s1 = s1.head()

# %%
df2 = s1.to_frame()

# %%
df2.reset_index(inplace=True)

# %%
df2.values.tolist()
# Out:
# [['Mercedes-Benz', 333],
#  ['BMW', 284],
#  ['Chevrolet', 253],
#  ['Ford', 185],
#  ['GMC', 163]]

# %%
df3 = df2.values.tolist()

# %%
answer_dict["Q2"] = df3

# %%
answer_dict["Q2"]
# Out:
# [['Mercedes-Benz', 333],
#  ['BMW', 284],
#  ['Chevrolet', 253],
#  ['Ford', 185],
#  ['GMC', 163]]

# %%
#Q3
df["Fuel Type"].unique()
# Out:
# array(['Regular', 'Premium', 'Diesel', 'Premium and Electricity',
#        'Premium or E85', 'Premium Gas or Electricity', 'Gasoline or E85',
#        'Gasoline or natural gas', 'CNG', 'Regular Gas or Electricity',
#        'Midgrade', 'Regular Gas and Electricity', 'Gasoline or propane'],
#       dtype=object)

# %%
fuel_type = df["Fuel Type"].unique()

# %%
fuel_type.sort()

# %%
answer_dict["Q3"] = fuel_type

# %%
answer_dict["Q3"]
# Out:
# array(['CNG', 'Diesel', 'Gasoline or E85', 'Gasoline or natural gas',
#        'Gasoline or propane', 'Midgrade', 'Premium',
#        'Premium Gas or Electricity', 'Premium and Electricity',
#        'Premium or E85', 'Regular', 'Regular Gas and Electricity',
#        'Regular Gas or Electricity'], dtype=object)

# %%
#6
df1 = df.query("Make == 'Toyota' or Make == 'Ford' or Make == 'Volkswagen' or Make == 'Nissan' or Make == 'Honda'")

# %%
df1.sort_values(['Make', 'CO2 Emission Grams/Mile']).groupby('Make').head()
# Out:
#              Make                         Model  Year  Engine Displacement  \
# 13412        Ford  Fusion Energi Plug-in Hybrid  2017                  2.0
# 11639        Ford   C-MAX Energi Plug-in Hybrid  2013                  2.0
# 11640        Ford   C-MAX Energi Plug-in Hybrid  2014                  2.0
# 11641        Ford   C-MAX Energi Plug-in Hybrid  2015                  2.0
# 11642        Ford   C-MAX Energi Plug-in Hybrid  2016                  2.0
# 17059       Honda         Accord Plug-in Hybrid  2014                  2.0
# 17522       Honda                       Insight  2000                  1.0
# 17524       Honda                       Insight  2001                  1.0
# 17526       Honda                       Insight  2002                  1.0
# 17528       Honda                       Insight  2003                  1.0
# 27201      Nissan                         Versa  2014                  1.6
# ...

# %%
df2 = df1.sort_values(['Make', 'CO2 Emission Grams/Mile']).groupby('Make').head()

# %%
df3 = df2.filter(items=['Make', 'CO2 Emission Grams/Mile'])

# %%
df4 = df3.groupby('Make')['CO2 Emission Grams/Mile'].apply(list).reset_index(name='CO2 Emission Grams/Mile')

# %%
df5 = df4.values.tolist()

# %%
l = df5

# %%
results = []
for x in l:
    m = [x[0]]
    new_list = m + x[1]
    results.append(new_list)

# %%
answer_dict["Q6"] = results

# %%
answer_dict["Q6"]
# Out:
# [['Ford', 112.0, 129.0, 129.0, 129.0, 129.0],
#  ['Honda',
#   130.0,
#   167.67924528301887,
#   167.67924528301887,
#   167.67924528301887,
#   167.67924528301887],
#  ['Nissan', 249.0, 254.0, 254.5, 254.5, 254.5],
#  ['Toyota', 133.0, 133.0, 133.0, 133.0, 158.0],
#  ['Volkswagen', 200.0, 200.0, 200.0, 200.0, 261.025641025641]]

# %%
#Q7
period_length = 5
start_year = df['Year'].min()
end_year = df['Year'].max()

# %%
for y in range(start_year, end_year, period_length):
    print(y)
# Out:
# 1984
# 1989
# 1994
# 1999
# 2004
# 2009
# 2014

# %%
median_in_range = 0

# %%
medians = []

# %%
for y in range(start_year, end_year, period_length):
    df1 = df[(df['Year'] >= y) & (df['Year'] < y + period_length)]
    print(df1['Combined MPG'].median())
# Out:
# 19.0
# 18.0
# 19.0
# 19.0
# 19.0
# 21.0
# 22.0

# %%
df[(df['Year'] >= 1984) & (df['Year'] < 1984 + 5)]
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35318             Volvo                  780  1988                  2.8
# 35924              Yugo                   GV  1988                  1.1
# 35925              Yugo                   GV  1988                  1.3
# 35928              Yugo               GV/GVX  1987                  1.1
# 35931              Yugo          Gy/yugo GVX  1986                  1.1
#
#        Cylinders     Transmission         Drivetrain  \
# ...

# %%
for y in range(start_year, end_year, period_length):
    df1 = df[(df['Year'] >= y) & (df['Year'] < y + period_length)]
    medians.append(df1['Combined MPG'].median())

# %%
medians = []

# %%
for y in range(start_year, end_year, period_length):
    df1 = df[(df['Year'] >= y) & (df['Year'] < y + period_length)]
    median_in_range = df1['Combined MPG'].median()
    medians.append([(y, y + period_length - 1), median_in_range])

# %%
answer_dict["Q7"] = medians

# %%
answer_dict["Q7"]
# Out:
# [[(1984, 1988), 19.0],
#  [(1989, 1993), 18.0],
#  [(1994, 1998), 19.0],
#  [(1999, 2003), 19.0],
#  [(2004, 2008), 19.0],
#  [(2009, 2013), 21.0],
#  [(2014, 2018), 22.0]]

# %%
#Q5
df1 = df.query("Transmission == 'Manual 5-spd' & `Fuel Type` == 'Regular' & Model == 'Golf'")

# %%
df2 = df1.filter(items=['Year','Combined MPG'])

# %%
df3 = df2.diff()

# %%
df3 = df3.filter(items=['Combined MPG'])

# %%
df3 = df3.rename(columns={'Combined MPG':'Diff'})

# %%
df4 = df2.join(df3).values.tolist()

# %%
answer_dict["Q5"] = df4

# %%
answer_dict["Q5"]
# Out:
# [[1986.0, 26.0, nan],
#  [1987.0, 26.0, 0.0],
#  [1988.0, 25.0, -1.0],
#  [1989.0, 25.0, 0.0],
#  [1999.0, 24.0, -1.0],
#  [2000.0, 24.0, 0.0],
#  [2001.0, 24.0, 0.0],
#  [2002.0, 24.0, 0.0],
#  [2003.0, 24.0, 0.0],
#  [2004.0, 24.0, 0.0],
#  [2005.0, 24.0, 0.0],
#  [2006.0, 24.0, 0.0],
#  [2010.0, 25.0, 1.0],
#  [2011.0, 26.0, 1.0],
#  [2012.0, 26.0, 0.0],
#  [2013.0, 26.0, 0.0],
#  [2015.0, 30.0, 4.0],
#  [2016.0, 30.0, 0.0],
#  [2017.0, 29.0, -1.0]]

# %%
answer_dict
# Out:
# {'Q1': 475.31633925715045,
#  'Q2': [['Mercedes-Benz', 333],
#   ['BMW', 284],
#   ['Chevrolet', 253],
#   ['Ford', 185],
#   ['GMC', 163]],
#  'Q3': array(['CNG', 'Diesel', 'Gasoline or E85', 'Gasoline or natural gas',
#         'Gasoline or propane', 'Midgrade', 'Premium',
#         'Premium Gas or Electricity', 'Premium and Electricity',
#         'Premium or E85', 'Regular', 'Regular Gas and Electricity',
#         'Regular Gas or Electricity'], dtype=object),
#  'Q4': None,
#  'Q5': [[1986.0, 26.0, nan],
#   [1987.0, 26.0, 0.0],
#   [1988.0, 25.0, -1.0],
#   [1989.0, 25.0, 0.0],
#   [1999.0, 24.0, -1.0],
#   [2000.0, 24.0, 0.0],
#   [2001.0, 24.0, 0.0],
#   [2002.0, 24.0, 0.0],
#   [2003.0, 24.0, 0.0],
#   [2004.0, 24.0, 0.0],
#   [2005.0, 24.0, 0.0],
#   [2006.0, 24.0, 0.0],
#   [2010.0, 25.0, 1.0],
#   [2011.0, 26.0, 1.0],
#   [2012.0, 26.0, 0.0],
#   [2013.0, 26.0, 0.0],
#   [2015.0, 30.0, 4.0],
#   [2016.0, 30.0, 0.0],
#   [2017.0, 29.0, -1.0]],
# ...
